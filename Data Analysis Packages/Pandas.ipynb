# %% [markdown]
# PANDAS
#
# To represent tabular data, pandas uses a custom data structure called a dataframe. A dataframe is a highly efficient, 2-dimensional data structure that provides a suite of methods and attributes to quickly explore, analyze, and visualize data. The dataframe is similar to the NumPy 2D array but adds support for many features that help you work with tabular data.
#
# One of the biggest advantages that pandas has over NumPy is the ability to store mixed data types in rows and columns. Many tabular datasets contain a range of data types and pandas dataframes handle mixed data types effortlessly while NumPy doesn't. Pandas dataframes can also handle missing values gracefully using a custom object, NaN, to represent those values. A common complaint with NumPy is its lack of an object to represent missing values and people end up having to find and replace these values manually. In addition, pandas dataframes contain axis labels for both rows and columns and enable you to refer to elements in the dataframe more intuitively. Since many tabular datasets contain column titles, this means that dataframes preserve the metadata from the file around the data.

# %% [markdown]
# In this tutorial, we'll use Pandas to analyze data on video game reviews.
# In order to be able to work with the data in Python, we'll need to read the csv file into a Pandas DataFrame. A DataFrame is a way to represent and work with tabular data. Tabular data has rows and columns, just like our csv file.
#
# Let's learn some basics of Pandas first.

# %%
import pandas as pd

# %% [markdown]
# We can create a Series manually to better understand how it works.
# To create a Series, we pass a list or NumPy array into the Series object when we instantiate it:

# %%
s1 = pd.Series([1,2])
s1
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s2 = pd.Series(['Pandas', 'are', 'better', 'than', 'Numpy', 99, 100])
s2
# Out:
# 0    Pandas
# 1       are
# 2    better
# 3      than
# 4     Numpy
# 5        99
# 6       100
# dtype: object

# %%
print(s2[5])
type(s2[5])
# Out:
# 99
# int

# %% [markdown]
# Creating A DataFrame in Pandas
# We can create a DataFrame by passing multiple Series into the DataFrame class. Here, we pass in the two Series objects we just created, s1 as the first row, and s2 as the second row.

# %%
s2 = pd.Series(['Python', 'Programming'])
df = pd.DataFrame([s1,s2])
df.head()
# Out:
#         0            1
# 0       1            2
# 1  Python  Programming

# %%
pd.DataFrame(
    [
        [1,2],
        ['Python', 'Programming']
    ]
)
# Out:
#         0            1
# 0       1            2
# 1  Python  Programming

# %%
pd.DataFrame(
    [
        [1,2],
        ['Python', 'Programming']
    ],
    columns=["column1", "column2"]
)
# Out:
#   column1      column2
# 0       1            2
# 1  Python  Programming

# %%
# pandas series from dictionary
a_d ={'name': 'Scooby', 'city': 'Delhi', 'email': 'scooby@gmail.com'}
print (a_d)
print('-'*100)
s = pd.Series(a_d)
s
# Out:
# {'name': 'Scooby', 'city': 'Delhi', 'email': 'scooby@gmail.com'}
# ----------------------------------------------------------------------------------------------------
# name               Scooby
# city                Delhi
# email    scooby@gmail.com
# dtype: object

# %%
print(s.loc['name'])
print(s.iloc[0])
# Out:
# Scooby
# Scooby

# %%
# pandas series from dictionary of lists
data ={'name': ['Scooby', 'Tom', 'Jerry'], 
      'city': ['Delhi', 'Gurgaon', 'Delhi'], 
      'email': ['scooby@gmail.com', 'tom@gmail.com', 'jerry@gmail.com']}

print (data)
print('-'*100)

s = pd.DataFrame(data)
s
# Out:
# {'name': ['Scooby', 'Tom', 'Jerry'], 'city': ['Delhi', 'Gurgaon', 'Delhi'], 'email': ['scooby@gmail.com', 'tom@gmail.com', 'jerry@gmail.com']}
# ----------------------------------------------------------------------------------------------------
#      name     city             email
# 0  Scooby    Delhi  scooby@gmail.com
# 1     Tom  Gurgaon     tom@gmail.com
# 2   Jerry    Delhi   jerry@gmail.com

# %%
print(s.loc[0])
print(s.iloc[0])
# Out:
# name               Scooby
# city                Delhi
# email    scooby@gmail.com
# Name: 0, dtype: object
# name               Scooby
# city                Delhi
# email    scooby@gmail.com
# Name: 0, dtype: object

# %% [markdown]
# In order to read in Video Gamres Reviews data, we'll need to use the pandas.read_csv function. This function will take in a csv file and return a DataFrame. The below code will:

# %%
reviews = pd.read_csv("ign.csv")
reviews
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# 18623                                             Inside
# 18624                                             Inside
#
#                                                      url          platform  \
# 0                 /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 1      /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 2                              /games/splice/ipad-141070              iPad
# 3                          /games/nhl-13/xbox-360-128182          Xbox 360
# 4                               /games/nhl-13/ps3-128181     PlayStation 3
# ...                                                  ...               ...
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...             Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...     PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681     PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435          Xbox One
# 18624                 /games/inside-playdead/pc-20055740                PC
#
#        score              genre editors_choice  release_year  release_month  \
# 0        9.0         Platformer              Y          2012              9
# 1        9.0         Platformer              Y          2012              9
# 2        8.5             Puzzle              N          2012              9
# 3        8.5             Sports              N          2012              9
# 4        8.5             Sports              N          2012              9
# ...      ...                ...            ...           ...            ...
# 18620    7.6                RPG              N          2016              6
# 18621    9.0  Action, Adventure              Y          2016              6
# 18622    5.8                RPG              N          2016              6
# 18623   10.0          Adventure              Y          2016              6
# 18624   10.0          Adventure              Y          2016              6
#
#        release_day
# 0               12
# 1               12
# 2               12
# 3               11
# 4               11
# ...            ...
# 18620           29
# 18621           29
# 18622           28
# 18623           28
# 18624           28
#
# [18625 rows x 11 columns]

# %% [markdown]
# Once we read in a DataFrame, Pandas gives us two methods that make it fast to print out the data. These functions are:
# * pandas.DataFrame.head -- prints the first N rows of a DataFrame. By default 5.
# * pandas.DataFrame.tail -- prints the last N rows of a DataFrame. By default 5.
#
# We'll use the head method to see what's in reviews:

# %%
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
# dataframe.columns will provide the column list of dataset as shown in code below:
print(reviews.columns)
# Out:
# Index(['Unnamed: 0', 'score_phrase', 'title', 'url', 'platform', 'score',
#        'genre', 'editors_choice', 'release_year', 'release_month',
#        'release_day'],
#       dtype='object')

# %% [markdown]
# The columns contain information about that game:
#
# * score_phrase — how IGN described the game in one word. This is linked to the score it received.
# * title — the name of the game.
# * url — the URL where you can see the full review.
# * platform — the platform the game was reviewed on (PC, PS4, etc).
# * score — the score for the game, from 1.0 to 10.0.
# * genre — the genre of the game.
# * editors_choice — N if the game wasn't an editor's choice, Y if it was. This is tied to score.
# * release_year — the year the game was released.
# * release_month — the month the game was released.
# * release_day — the day the game was released.

# %%
reviews.shape # returns rows and columns count of data set
# Out:
# (18625, 11)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18625 entries, 0 to 18624
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      18625 non-null  int64
#  1   score_phrase    18625 non-null  object
#  2   title           18625 non-null  object
#  3   url             18625 non-null  object
#  4   platform        18625 non-null  object
#  5   score           18625 non-null  float64
#  6   genre           18589 non-null  object
#  7   editors_choice  18625 non-null  object
#  8   release_year    18625 non-null  int64
#  9   release_month   18625 non-null  int64
#  10  release_day     18625 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.6+ MB

# %%
reviews.describe()
# Out:
#          Unnamed: 0         score  release_year  release_month   release_day
# count  18625.000000  18625.000000  18625.000000    18625.00000  18625.000000
# mean    9312.000000      6.950459   2006.515329        7.13847     15.603866
# std     5376.718717      1.711736      4.587529        3.47671      8.690128
# min        0.000000      0.500000   1970.000000        1.00000      1.000000
# 25%     4656.000000      6.000000   2003.000000        4.00000      8.000000
# 50%     9312.000000      7.300000   2007.000000        8.00000     16.000000
# 75%    13968.000000      8.200000   2010.000000       10.00000     23.000000
# max    18624.000000     10.000000   2016.000000       12.00000     31.000000

# %% [markdown]
# - percentile calculation is based on below formula:
#   min+(max-min)*percentile
#
# - linear: i + (j - i) * fraction, where fraction is the fractional part of the index surrounded by i and j

# %%
data_1 = pd.DataFrame({'One':[4,6,8,10]},columns=['One'])
# res_25 = 4 + (6-4)*(3/4) =  5.5
# res_75 = 8 + (10-8)*(1/4) = 8.5
data_1.describe()
# Out:
#              One
# count   4.000000
# mean    7.000000
# std     2.581989
# min     4.000000
# 25%     5.500000
# 50%     7.000000
# 75%     8.500000
# max    10.000000

# %% [markdown]
# As you can see, everything has been read in properly
# * we have 18625 rows and 11 columns.
#
# One of the big advantages of Pandas vs just using NumPy is that Pandas allows you to have columns with different data types. DataFrame reviews has columns that store float values, like score, string values, like score_phrase, and integers, like release_year.

# %%
 # Indexing DataFrames with Pandas using the pandas.DataFrame.iloc method
 # he below code will replicate reviews.head():
 reviews.iloc[:5, :]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
# Here are some indexing examples, along with the results:
# the entire DataFrame.
reviews.iloc[:,:]
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# 18623                                             Inside
# 18624                                             Inside
#
#                                                      url          platform  \
# 0                 /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 1      /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 2                              /games/splice/ipad-141070              iPad
# 3                          /games/nhl-13/xbox-360-128182          Xbox 360
# 4                               /games/nhl-13/ps3-128181     PlayStation 3
# ...                                                  ...               ...
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...             Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...     PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681     PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435          Xbox One
# 18624                 /games/inside-playdead/pc-20055740                PC
#
#        score              genre editors_choice  release_year  release_month  \
# 0        9.0         Platformer              Y          2012              9
# 1        9.0         Platformer              Y          2012              9
# 2        8.5             Puzzle              N          2012              9
# 3        8.5             Sports              N          2012              9
# 4        8.5             Sports              N          2012              9
# ...      ...                ...            ...           ...            ...
# 18620    7.6                RPG              N          2016              6
# 18621    9.0  Action, Adventure              Y          2016              6
# 18622    5.8                RPG              N          2016              6
# 18623   10.0          Adventure              Y          2016              6
# 18624   10.0          Adventure              Y          2016              6
#
#        release_day
# 0               12
# 1               12
# 2               12
# 3               11
# 4               11
# ...            ...
# 18620           29
# 18621           29
# 18622           28
# 18623           28
# 18624           28
#
# [18625 rows x 11 columns]

# %%
# rows from position 5 onwards, and columns from position 5 onwards
reviews.iloc[5:, 5:]
# Out:
#        score              genre editors_choice  release_year  release_month  \
# 5        7.0           Strategy              N          2012              9
# 6        3.0           Fighting              N          2012              9
# 7        9.0                RPG              Y          2012              9
# 8        3.0           Fighting              N          2012              9
# 9        7.0           Strategy              N          2012              9
# ...      ...                ...            ...           ...            ...
# 18620    7.6                RPG              N          2016              6
# 18621    9.0  Action, Adventure              Y          2016              6
# 18622    5.8                RPG              N          2016              6
# 18623   10.0          Adventure              Y          2016              6
# 18624   10.0          Adventure              Y          2016              6
#
#        release_day
# 5               11
# 6               11
# 7               11
# 8               11
# 9               11
# ...            ...
# 18620           29
# 18621           29
# 18622           28
# 18623           28
# 18624           28
#
# [18620 rows x 6 columns]

# %%
# the first column, and all of the rows for the column.
reviews.iloc[:,0]
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 18620    18620
# 18621    18621
# 18622    18622
# 18623    18623
# 18624    18624
# Name: Unnamed: 0, Length: 18625, dtype: int64

# %%
# the 10th row, and all of the columns for that row.
reviews.iloc[9,:]
# Out:
# Unnamed: 0                                                9
# score_phrase                                           Good
# title                             Total War Battles: Shogun
# url               /games/total-war-battles-shogun/pc-142564
# platform                                                 PC
# score                                                     7
# genre                                              Strategy
# editors_choice                                            N
# release_year                                           2012
# release_month                                             9
# release_day                                              11
# Name: 9, dtype: object

# %%
# Now that we know how to index by position, let's remove the first column, which doesn't have any useful information:
reviews = reviews.iloc[:, 1:]
reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
reviews.iloc[:3, 1:]
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12

# %%
reviews.loc[:3]
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11

# %% [markdown]
# Pandas Series
# The Series object is a core data structure that pandas uses to represent rows and columns. A Series is a labelled collection of values similar to the NumPy vector. The main advantage of Series objects is the ability to utilize non-integer labels. NumPy arrays can only utilize integer labels for indexing.

# %%
reviews["score"]
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
#          ...
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# Name: score, Length: 18625, dtype: float64

# %%
# We can also use lists of columns with this method:
reviews[["score", "release_year"]]
# Out:
#        score  release_year
# 0        9.0          2012
# 1        9.0          2012
# 2        8.5          2012
# 3        8.5          2012
# 4        8.5          2012
# ...      ...           ...
# 18620    7.6          2016
# 18621    9.0          2016
# 18622    5.8          2016
# 18623   10.0          2016
# 18624   10.0          2016
#
# [18625 rows x 2 columns]

# %%
# We can verify that a single column is a Series:
type(reviews['score'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###  Math Functions with Pandas

# %%
# Pandas DataFrame Methods
reviews["score"].mean()  # gets mean of column
# Out:
# 6.950459060402666

# %%
# to get mean of each row
reviews.mean(axis=1)
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
#           ...
# 18620    514.650
# 18621    515.000
# 18622    513.950
# 18623    515.000
# 18624    515.000
# Length: 18625, dtype: float64

# %%
reviews['score'].count()
# Out:
# 18625

# %%
reviews.max()
# Out:
# score_phrase                       Unbearable
# title                 xXx: State of the Union
# url               /games/zusar-vasar/dc-13794
# platform                                 iPod
# score                                      10
# editors_choice                              Y
# release_year                             2016
# release_month                              12
# release_day                                31
# dtype: object

# %%
reviews.min()
# Out:
# score_phrase                                     Amazing
# title                                             #IDARB
# url               /games/0-d-beat-drop/xbox-360-14342395
# platform                                         Android
# score                                                0.5
# editors_choice                                         N
# release_year                                        1970
# release_month                                          1
# release_day                                            1
# dtype: object

# %%
reviews.median()
# Out:
# score               7.3
# release_year     2007.0
# release_month       8.0
# release_day        16.0
# dtype: float64

# %%
reviews.std()
# Out:
# score            1.711736
# release_year     4.587529
# release_month    3.476710
# release_day      8.690128
# dtype: float64

# %% [markdown]
# All the common mathematical operators that work in Python, like +, -, *, /, and ^ will work, and will apply to each element in a DataFrame or a Series.

# %%
reviews['score'] / 2
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
#          ...
# 18620    3.80
# 18621    4.50
# 18622    2.90
# 18623    5.00
# 18624    5.00
# Name: score, Length: 18625, dtype: float64

# %%
score_filter = reviews["score"] > 7
score_filter
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18620     True
# 18621     True
# 18622    False
# 18623     True
# 18624     True
# Name: score, Length: 18625, dtype: bool

# %%
filtered_reviews = reviews[score_filter]
filtered_reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
# When filtering with multiple conditions, it's important to put each condition in parentheses, 
# and separate them with a single ampersand (&) or pip (|) depending upon filtering criteria.
xbox_one_filter = (reviews["score"] > 7) & (reviews["platform"] == "Xbox One")
filtered_reviews = reviews[xbox_one_filter]
filtered_reviews.head()
# Out:
#       score_phrase                     title  \
# 17137      Amazing                 Gone Home
# 17197      Amazing            Rayman Legends
# 17295      Amazing  LEGO Marvel Super Heroes
# 17313        Great             Dead Rising 3
# 17317        Great           Killer Instinct
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# 17295  /games/lego-marvel-super-heroes/xbox-one-20000826  Xbox One    9.0
# 17313               /games/dead-rising-3/xbox-one-124306  Xbox One    8.3
# 17317      /games/killer-instinct-2013/xbox-one-20000538  Xbox One    8.4
#
#             genre editors_choice  release_year  release_month  release_day
# 17137  Simulation              Y          2013              8           15
# 17197  Platformer              Y          2013              8           26
# 17295      Action              Y          2013             10           22
# 17313      Action              N          2013             11           18
# 17317    Fighting              N          2013             11           18

# %% [markdown]
# GroupBY

# %%
reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
reviews.groupby(by=['score_phrase'])[['score']].max()
# Out:
#               score
# score_phrase
# Amazing         9.9
# Awful           3.9
# Bad             4.9
# Disaster        0.8
# Good            7.9
# Great           8.9
# Masterpiece    10.0
# Mediocre        5.9
# Okay            6.9
# Painful         2.9
# Unbearable      1.9

# %%
reviews.groupby(by=['platform', 'score_phrase'])[['score']].sum()
# Out:
#                        score
# platform score_phrase
# Android  Amazing        27.3
#          Good           95.7
#          Great         130.3
#          Mediocre       15.4
#          Okay           25.6
# ...                      ...
# iPod     Awful           3.0
#          Good           59.2
#          Great          24.5
#          Mediocre       10.0
#          Okay           12.7
#
# [352 rows x 1 columns]

# %%
import numpy as np
reviews.groupby(by=['score_phrase', 'platform']).agg({'score': [np.sum, np.min]})
# Out:
#                                score
#                                  sum amin
# score_phrase platform
# Amazing      Android            27.3  9.0
#              Arcade              9.4  9.4
#              Dreamcast         528.4  9.0
#              Game Boy           27.0  9.0
#              Game Boy Advance  477.9  9.0
# ...                              ...  ...
# Unbearable   Wii                21.6  1.0
#              Wireless            2.0  1.0
#              Xbox                5.9  1.0
#              Xbox 360            2.5  1.0
#              iPhone              1.0  1.0
#
# [352 rows x 2 columns]

# %%
# verify above result
reviews[(reviews['score_phrase']=='Amazing') & (reviews['platform']=='Android')]
# Out:
#       score_phrase         title                                url platform  \
# 84         Amazing  Puzzle Craft  /games/puzzlecraft/android-134352  Android
# 14783      Amazing         Drop7         /games/drop7/android-80717  Android
# 18032      Amazing        Threes     /games/threes/android-20014648  Android
#
#        score   genre editors_choice  release_year  release_month  release_day
# 84       9.0  Puzzle              Y          2012              8           17
# 14783    9.0  Puzzle              Y          2010              7           15
# 18032    9.3  Puzzle              Y          2014             12            9

# %% [markdown]
# Use of Lambda or Apply function in Pandas
#
# Let's add 100 to each score if its an even score

# %%
even_grp = reviews['score'].apply(lambda score: score+100 if score%2==0  else score)

# %%
even_grp
# Out:
# 0          9.0
# 1          9.0
# 2          8.5
# 3          8.5
# 4          8.5
#          ...
# 18620      7.6
# 18621      9.0
# 18622      5.8
# 18623    110.0
# 18624    110.0
# Name: score, Length: 18625, dtype: float64

# %% [markdown]
# Let's add 50 to each score if its an even score otherwise add 10 to each score

# %%
new_score= reviews['score'].apply(lambda score: score+50 if score%2==0  else score+10)
new_score
# Out:
# 0        19.0
# 1        19.0
# 2        18.5
# 3        18.5
# 4        18.5
#          ...
# 18620    17.6
# 18621    19.0
# 18622    15.8
# 18623    60.0
# 18624    60.0
# Name: score, Length: 18625, dtype: float64

# %%
reviews[['score', 'release_month']]
# Out:
#        score  release_month
# 0        9.0              9
# 1        9.0              9
# 2        8.5              9
# 3        8.5              9
# 4        8.5              9
# ...      ...            ...
# 18620    7.6              6
# 18621    9.0              6
# 18622    5.8              6
# 18623   10.0              6
# 18624   10.0              6
#
# [18625 rows x 2 columns]

# %%
reviews[['score', 'release_month']].apply(np.median)
# Out:
# score            7.3
# release_month    8.0
# dtype: float64

# %%
def even_score(series):
    if series%2 == 0:
        series = series + 100
        return series
    else:
        return series

# %%
grp = reviews['score'].apply(even_score)
grp
# Out:
# 0          9.0
# 1          9.0
# 2          8.5
# 3          8.5
# 4          8.5
#          ...
# 18620      7.6
# 18621      9.0
# 18622      5.8
# 18623    110.0
# 18624    110.0
# Name: score, Length: 18625, dtype: float64

# %%
def odd_score(series):
    if series['score']%2 != 0 and series['platform']=='PlayStation 3':
        series['score'] = series['score'] + 100
        return series
    else:
        series['score'] = series['score'] + 10
        return series

# %%
grp = reviews[['score', 'platform']].apply(odd_score, axis=1)
grp
# Out:
#        score          platform
# 0       19.0  PlayStation Vita
# 1       19.0  PlayStation Vita
# 2       18.5              iPad
# 3       18.5          Xbox 360
# 4      108.5     PlayStation 3
# ...      ...               ...
# 18620   17.6             Wii U
# 18621   19.0     PlayStation 4
# 18622   15.8     PlayStation 4
# 18623   20.0          Xbox One
# 18624   20.0                PC
#
# [18625 rows x 2 columns]

# %%
# use labda with apply majorly when you want to transform one column only 
grp = reviews[['score', 'platform']].apply(lambda x: x['score']+200 if x['platform']=='PlayStation 3' else x['score']+10, axis=1)
grp
# Out:
# 0         19.0
# 1         19.0
# 2         18.5
# 3         18.5
# 4        208.5
#          ...
# 18620     17.6
# 18621     19.0
# 18622     15.8
# 18623     20.0
# 18624     20.0
# Length: 18625, dtype: float64

# %%
reviews.groupby('platform')['score'].sum().plot(kind='bar')

# %%
reviews.groupby('platform')['score'].sum().plot(kind='bar', figsize=(30, 15), grid=True, legend=True)

# %%
reviews
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# ...            ...                                                ...
# 18620         Good                          Tokyo Mirage Sessions #FE
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18622     Mediocre            Star Ocean: Integrity and Faithlessness
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                                                      url          platform  \
# 0                 /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 1      /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 2                              /games/splice/ipad-141070              iPad
# 3                          /games/nhl-13/xbox-360-128182          Xbox 360
# 4                               /games/nhl-13/ps3-128181     PlayStation 3
# ...                                                  ...               ...
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...             Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...     PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681     PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435          Xbox One
# 18624                 /games/inside-playdead/pc-20055740                PC
#
#        score              genre editors_choice  release_year  release_month  \
# 0        9.0         Platformer              Y          2012              9
# 1        9.0         Platformer              Y          2012              9
# 2        8.5             Puzzle              N          2012              9
# 3        8.5             Sports              N          2012              9
# 4        8.5             Sports              N          2012              9
# ...      ...                ...            ...           ...            ...
# 18620    7.6                RPG              N          2016              6
# 18621    9.0  Action, Adventure              Y          2016              6
# 18622    5.8                RPG              N          2016              6
# 18623   10.0          Adventure              Y          2016              6
# 18624   10.0          Adventure              Y          2016              6
#
#        release_day
# 0               12
# 1               12
# 2               12
# 3               11
# 4               11
# ...            ...
# 18620           29
# 18621           29
# 18622           28
# 18623           28
# 18624           28
#
# [18625 rows x 10 columns]

# %%
reviews.groupby(['score_phrase'])['score'].sum().plot(kind='bar', figsize=(20, 15), grid=True, legend=True)

# %%
reviews.groupby(['release_year'])['score'].sum().plot(kind='line', figsize=(25, 15), grid=True, legend=True)

# %%
reviews['score'].plot(kind='box', figsize=(20, 15), grid=True, legend=True)

# %%
reviews['score'].describe()
# Out:
# count    18625.000000
# mean         6.950459
# std          1.711736
# min          0.500000
# 25%          6.000000
# 50%          7.300000
# 75%          8.200000
# max         10.000000
# Name: score, dtype: float64

# %%
reviews['score'].median()
# Out:
# 7.3

# %%
reviews[reviews['score']<4]
# Out:
#       score_phrase                            title  \
# 6            Awful              Double Dragon: Neon
# 8            Awful              Double Dragon: Neon
# 59         Painful                         Hoodwink
# 89           Awful                      Mugen Souls
# 102        Painful  Naughty Bear: Panic in Paradise
# ...            ...                              ...
# 18299        Awful         Tony Hawk's Pro Skater 5
# 18402   Unbearable             Rugby World Cup 2015
# 18431        Awful                    Devil's Third
# 18513        Awful                   Umbrella Corps
# 18516        Awful                   Alekhine's Gun
#
#                                                      url       platform  \
# 6              /games/double-dragon-neon/xbox-360-131320       Xbox 360
# 8                   /games/double-dragon-neon/ps3-131321  PlayStation 3
# 59                             /games/hoodwink/pc-136672             PC
# 89                         /games/mugen-souls/ps3-120256  PlayStation 3
# 102    /games/naughty-bear-panic-in-paradise/xbox-360...       Xbox 360
# ...                                                  ...            ...
# 18299        /games/tony-hawks-pro-skater-5/ps4-20027407  PlayStation 4
# 18402           /games/rugby-world-cup-2015/ps4-20042497  PlayStation 4
# 18431                 /games/devils-third/wii-u-20019887          Wii U
# 18513   /games/resident-evil-umbrella-corps/ps4-20042903  PlayStation 4
# 18516                      /games/alekhines-gun/pc-76711             PC
#
#        score          genre editors_choice  release_year  release_month  \
# 6        3.0       Fighting              N          2012              9
# 8        3.0       Fighting              N          2012              9
# 59       2.5      Adventure              N          2012              8
# 89       3.9  Strategy, RPG              N          2012             10
# 102      2.3         Action              N          2012             10
# ...      ...            ...            ...           ...            ...
# 18299    3.5         Sports              N          2015             10
# 18402    1.5         Sports              N          2015              9
# 18431    3.5         Action              N          2015              8
# 18513    3.8        Shooter              N          2016              6
# 18516    3.0         Action              N          2016              3
#
#        release_day
# 6               11
# 8               11
# 59              23
# 89              12
# 102             18
# ...            ...
# 18299            2
# 18402            4
# 18431           28
# 18513           24
# 18516           11
#
# [1079 rows x 10 columns]

# %%
# broadcasted
grp = reviews[['score', 'platform']].apply(lambda x: x['score']+200 if x['platform']=='PlayStation 3' else x['score']+10, axis=1)
grp
# Out:
# 0         19.0
# 1         19.0
# 2         18.5
# 3         18.5
# 4        208.5
#          ...
# 18620     17.6
# 18621     19.0
# 18622     15.8
# 18623     20.0
# 18624     20.0
# Length: 18625, dtype: float64

# %%
# let's add some Null values in our grp dataset
grp.replace(19, np.nan, inplace=True)
grp
# Out:
# 0          NaN
# 1          NaN
# 2         18.5
# 3         18.5
# 4        208.5
#          ...
# 18620     17.6
# 18621      NaN
# 18622     15.8
# 18623     20.0
# 18624     20.0
# Length: 18625, dtype: float64

# %%
grp.dropna()[0:50]
# Out:
# 2      18.5
# 3      18.5
# 4     208.5
# 5      17.0
# 6      13.0
# 8     203.0
# 9      17.0
# 10    207.5
# 11     17.5
# 12     17.0
# 15     16.5
# 16     16.5
# 17     18.0
# 18    205.5
# 19     17.0
# 20    207.0
# 21     17.5
# 22    207.5
# 23     17.5
# 25     17.0
# 27     17.5
# 28     18.0
# 29    206.5
# 31     18.7
# 32    204.9
# 33     19.6
# 34     17.3
# 35     19.6
# 36     16.5
# 39    209.0
# 40     18.5
# 41     18.0
# 42    208.5
# 43     18.5
# 44     18.5
# 45     19.2
# 46    207.9
# 47     17.9
# 48     17.0
# 49     16.9
# 50     19.1
# 51     18.0
# 52     19.5
# 53    208.0
# 54     19.5
# 55     18.0
# 56     16.0
# 57    209.0
# 59     12.5
# 60    209.1
# dtype: float64

# %%
grp.replace(np.nan, '0')[0:10]
# Out:
# 0        0
# 1        0
# 2     18.5
# 3     18.5
# 4    208.5
# 5       17
# 6       13
# 7        0
# 8      203
# 9       17
# dtype: object

# %%
grp
# Out:
# 0          NaN
# 1          NaN
# 2         18.5
# 3         18.5
# 4        208.5
#          ...
# 18620     17.6
# 18621      NaN
# 18622     15.8
# 18623     20.0
# 18624     20.0
# Length: 18625, dtype: float64

# %%
grp.replace(np.nan, '0', inplace = True)

# %%
grp[0:10]
# Out:
# 0        0
# 1        0
# 2     18.5
# 3     18.5
# 4    208.5
# 5       17
# 6       13
# 7        0
# 8      203
# 9       17
# dtype: object

# %%
grp.replace('0', np.nan, inplace = True)

# %%
grp[0:3]
# Out:
# 0     NaN
# 1     NaN
# 2    18.5
# dtype: float64

# %%
grp.fillna(0, inplace = True)

# %%
grp[0:5]
# Out:
# 0      0.0
# 1      0.0
# 2     18.5
# 3     18.5
# 4    208.5
# dtype: float64

# %%
reviews_low_score = reviews[reviews['score']<4].copy()
reviews_low_score
# Out:
#       score_phrase                            title  \
# 6            Awful              Double Dragon: Neon
# 8            Awful              Double Dragon: Neon
# 59         Painful                         Hoodwink
# 89           Awful                      Mugen Souls
# 102        Painful  Naughty Bear: Panic in Paradise
# ...            ...                              ...
# 18299        Awful         Tony Hawk's Pro Skater 5
# 18402   Unbearable             Rugby World Cup 2015
# 18431        Awful                    Devil's Third
# 18513        Awful                   Umbrella Corps
# 18516        Awful                   Alekhine's Gun
#
#                                                      url       platform  \
# 6              /games/double-dragon-neon/xbox-360-131320       Xbox 360
# 8                   /games/double-dragon-neon/ps3-131321  PlayStation 3
# 59                             /games/hoodwink/pc-136672             PC
# 89                         /games/mugen-souls/ps3-120256  PlayStation 3
# 102    /games/naughty-bear-panic-in-paradise/xbox-360...       Xbox 360
# ...                                                  ...            ...
# 18299        /games/tony-hawks-pro-skater-5/ps4-20027407  PlayStation 4
# 18402           /games/rugby-world-cup-2015/ps4-20042497  PlayStation 4
# 18431                 /games/devils-third/wii-u-20019887          Wii U
# 18513   /games/resident-evil-umbrella-corps/ps4-20042903  PlayStation 4
# 18516                      /games/alekhines-gun/pc-76711             PC
#
#        score          genre editors_choice  release_year  release_month  \
# 6        3.0       Fighting              N          2012              9
# 8        3.0       Fighting              N          2012              9
# 59       2.5      Adventure              N          2012              8
# 89       3.9  Strategy, RPG              N          2012             10
# 102      2.3         Action              N          2012             10
# ...      ...            ...            ...           ...            ...
# 18299    3.5         Sports              N          2015             10
# 18402    1.5         Sports              N          2015              9
# 18431    3.5         Action              N          2015              8
# 18513    3.8        Shooter              N          2016              6
# 18516    3.0         Action              N          2016              3
#
#        release_day
# 6               11
# 8               11
# 59              23
# 89              12
# 102             18
# ...            ...
# 18299            2
# 18402            4
# 18431           28
# 18513           24
# 18516           11
#
# [1079 rows x 10 columns]

# %%
reviews_low_score = reviews_low_score.reset_index()
reviews_low_score
# Out:
#       index score_phrase                            title  \
# 0         6        Awful              Double Dragon: Neon
# 1         8        Awful              Double Dragon: Neon
# 2        59      Painful                         Hoodwink
# 3        89        Awful                      Mugen Souls
# 4       102      Painful  Naughty Bear: Panic in Paradise
# ...     ...          ...                              ...
# 1074  18299        Awful         Tony Hawk's Pro Skater 5
# 1075  18402   Unbearable             Rugby World Cup 2015
# 1076  18431        Awful                    Devil's Third
# 1077  18513        Awful                   Umbrella Corps
# 1078  18516        Awful                   Alekhine's Gun
#
#                                                     url       platform  score  \
# 0             /games/double-dragon-neon/xbox-360-131320       Xbox 360    3.0
# 1                  /games/double-dragon-neon/ps3-131321  PlayStation 3    3.0
# 2                             /games/hoodwink/pc-136672             PC    2.5
# 3                         /games/mugen-souls/ps3-120256  PlayStation 3    3.9
# 4     /games/naughty-bear-panic-in-paradise/xbox-360...       Xbox 360    2.3
# ...                                                 ...            ...    ...
# 1074        /games/tony-hawks-pro-skater-5/ps4-20027407  PlayStation 4    3.5
# 1075           /games/rugby-world-cup-2015/ps4-20042497  PlayStation 4    1.5
# 1076                 /games/devils-third/wii-u-20019887          Wii U    3.5
# 1077   /games/resident-evil-umbrella-corps/ps4-20042903  PlayStation 4    3.8
# 1078                      /games/alekhines-gun/pc-76711             PC    3.0
#
#               genre editors_choice  release_year  release_month  release_day
# 0          Fighting              N          2012              9           11
# 1          Fighting              N          2012              9           11
# 2         Adventure              N          2012              8           23
# 3     Strategy, RPG              N          2012             10           12
# 4            Action              N          2012             10           18
# ...             ...            ...           ...            ...          ...
# 1074         Sports              N          2015             10            2
# 1075         Sports              N          2015              9            4
# 1076         Action              N          2015              8           28
# 1077        Shooter              N          2016              6           24
# 1078         Action              N          2016              3           11
#
# [1079 rows x 11 columns]

# %%
joined_df = pd.merge(reviews, reviews_low_score, left_on = 'score_phrase', right_on='score_phrase', how='right')
joined_df.shape
# Out:
# (561689, 20)

# %%
joined_df
# Out:
#        score_phrase                                  title_x  \
# 0             Awful                      Double Dragon: Neon
# 1             Awful                      Double Dragon: Neon
# 2             Awful                              Mugen Souls
# 3             Awful    LEGO The Lord of the Rings [Portable]
# 4             Awful    LEGO The Lord of the Rings [Portable]
# ...             ...                                      ...
# 561684     Disaster  Looney Tunes: Back in Action: Zany Race
# 561685     Disaster                      Action Girlz Racing
# 561686     Disaster                       Extreme PaintBrawl
# 561687     Disaster  Looney Tunes: Back in Action: Zany Race
# 561688     Disaster                      Action Girlz Racing
#
#                                                     url_x        platform_x  \
# 0               /games/double-dragon-neon/xbox-360-131320          Xbox 360
# 1                    /games/double-dragon-neon/ps3-131321     PlayStation 3
# 2                           /games/mugen-souls/ps3-120256     PlayStation 3
# 3       /games/lego-the-lord-of-the-rings-portable/3ds...      Nintendo 3DS
# 4       /games/lego-the-lord-of-the-rings-portable/vit...  PlayStation Vita
# ...                                                   ...               ...
# 561684  /games/looney-tunes-back-in-action-zany-race/c...          Wireless
# 561685              /games/action-girlz-racing/wii-889218               Wii
# 561686                 /games/extreme-paintbrawl/pc-10455                PC
# 561687  /games/looney-tunes-back-in-action-zany-race/c...          Wireless
# 561688              /games/action-girlz-racing/wii-889218               Wii
#
#         score_x            genre_x editors_choice_x  release_year_x  \
# 0           3.0           Fighting                N            2012
# 1           3.0           Fighting                N            2012
# 2           3.9      Strategy, RPG                N            2012
# 3           3.8  Action, Adventure                N            2012
# 4           3.8  Action, Adventure                N            2012
# ...         ...                ...              ...             ...
# 561684      0.5             Racing                N            2003
# 561685      0.8             Racing                N            2009
# 561686      0.7             Action                N            1998
# 561687      0.5             Racing                N            2003
# 561688      0.8             Racing                N            2009
#
#         release_month_x  release_day_x  index  \
# 0                     9             11      6
# 1                     9             11      6
# 2                    10             12      6
# 3                    11             26      6
# 4                    11             26      6
# ...                 ...            ...    ...
# 561684               10             28   5242
# 561685                2             11   5242
# 561686               10             29  12513
# 561687               10             28  12513
# 561688                2             11  12513
#
#                                         title_y  \
# 0                           Double Dragon: Neon
# 1                           Double Dragon: Neon
# 2                           Double Dragon: Neon
# 3                           Double Dragon: Neon
# 4                           Double Dragon: Neon
# ...                                         ...
# 561684  Looney Tunes: Back in Action: Zany Race
# 561685  Looney Tunes: Back in Action: Zany Race
# 561686                      Action Girlz Racing
# 561687                      Action Girlz Racing
# 561688                      Action Girlz Racing
#
#                                                     url_y platform_y  score_y  \
# 0               /games/double-dragon-neon/xbox-360-131320   Xbox 360      3.0
# 1               /games/double-dragon-neon/xbox-360-131320   Xbox 360      3.0
# 2               /games/double-dragon-neon/xbox-360-131320   Xbox 360      3.0
# 3               /games/double-dragon-neon/xbox-360-131320   Xbox 360      3.0
# 4               /games/double-dragon-neon/xbox-360-131320   Xbox 360      3.0
# ...                                                   ...        ...      ...
# 561684  /games/looney-tunes-back-in-action-zany-race/c...   Wireless      0.5
# 561685  /games/looney-tunes-back-in-action-zany-race/c...   Wireless      0.5
# 561686              /games/action-girlz-racing/wii-889218        Wii      0.8
# 561687              /games/action-girlz-racing/wii-889218        Wii      0.8
# 561688              /games/action-girlz-racing/wii-889218        Wii      0.8
#
#          genre_y editors_choice_y  release_year_y  release_month_y  \
# 0       Fighting                N            2012                9
# 1       Fighting                N            2012                9
# 2       Fighting                N            2012                9
# 3       Fighting                N            2012                9
# 4       Fighting                N            2012                9
# ...          ...              ...             ...              ...
# 561684    Racing                N            2003               10
# 561685    Racing                N            2003               10
# 561686    Racing                N            2009                2
# 561687    Racing                N            2009                2
# 561688    Racing                N            2009                2
#
#         release_day_y
# 0                  11
# 1                  11
# 2                  11
# 3                  11
# 4                  11
# ...               ...
# 561684             28
# 561685             28
# 561686             11
# 561687             11
# 561688             11
#
# [561689 rows x 20 columns]
