# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import seaborn as sns

# %%
#For Linear Regression using StatsModel Package
import statsmodels.api as stm
import scipy.stats as stats
# Linear Regression using Sklearn
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-19ecfd9b0d96> in <module>()
#       1 #For Linear Regression using StatsModel Package
# ----> 2 import statsmodels.api as stm
#       3 import scipy.stats as stats
#       4 # Linear Regression using Sklearn
#       5 import sklearn
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
cars = pd.read_csv("cars.csv")

# %%
# head of data
cars.head(5)
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# ## Objective
#
# ### Predict MPG of cars based on the weight of the cars
# ### Target(Response) Variable - MPG
# ### Explanatory Variable (Predictors) - Weight,HP

# %%
cars.isnull().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %% [markdown]
# ### Checking for zero's in MPG and Horsepower
# - Scatter plot between HP and MPG

# %%
plt.scatter(x = "MPG",y="Horsepower",data=cars)
plt.xlabel("MPG")
plt.ylabel("Horsepower")
plt.show()

# %%
## removing the data with zero values
cars2 = cars.loc[(cars['MPG'] !=0) & (cars['Horsepower'] != 0)]

# %%
plt.scatter(x = "MPG",y="Horsepower",data=cars2)
plt.xlabel("MPG")
plt.ylabel("Horsepower")
plt.show()

# %% [markdown]
# ## Scatter plot between HP,Weight,MPG

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(cars2[['MPG','Horsepower','Weight']],color = "green", alpha = 0.5, figsize = (14,10),
              diagonal = 'hist')
plt.show()
# Out:
# C:\Users\NiranjanKumar\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

# %%
sns.pairplot(cars2[['MPG','Horsepower','Weight']])

# %%
cars2[['MPG','Horsepower','Weight']].corr()
# Out:
#                  MPG  Horsepower    Weight
# MPG         1.000000   -0.778427 -0.832244
# Horsepower -0.778427    1.000000  0.864538
# Weight     -0.832244    0.864538  1.000000

# %% [markdown]
# ## Split Data for Model Fitting and Validation

# %%
#randomly divide the data into train (70%) and test(30%)

train = np.random.choice(cars2.index,round(0.7 * len(cars2)),replace=False)

# %%
# select the train observations from the main data set corresponding to the train data set
X_train = cars2.loc[train,["Weight",'Horsepower']]
y_train = cars2.loc[train,'MPG']

# %%
# Select the test observations from the data set

test = []

for i in cars2.index:
    if i not in train:
        test.append(i)
        
test = np.array(test)

# %%
# 4 - Slice the test data

X_test = cars2.loc[test,['Weight','Horsepower']]
y_test = cars2.loc[test,'MPG']

# %%
# Adding the constant to get the constant term for model
X_train = stm.add_constant(X_train) 
X_train.head()
# Out:
#      const  Weight  Horsepower
# 360    1.0    2190          74
# 35     1.0    2130          88
# 71     1.0    4135         150
# 56     1.0    2220          86
# 216    1.0    3270          88

# %% [markdown]
# ## Fitting of Model

# %%
# OLS Regression
model = stm.OLS(y_train,X_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.699
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     314.7
# Date:                Fri, 14 Sep 2018   Prob (F-statistic):           2.17e-71
# Time:                        12:39:50   Log-Likelihood:                -784.92
# No. Observations:                 274   AIC:                             1576.
# Df Residuals:                     271   BIC:                             1587.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         45.9858      0.971     47.372      0.000      44.075      47.897
# Weight        -0.0060      0.001    -10.269      0.000      -0.007      -0.005
# Horsepower    -0.0449      0.013     -3.502      0.001      -0.070      -0.020
# ==============================================================================
# Omnibus:                       18.369   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.571
# Skew:                           0.589   Prob(JB):                     3.41e-05
# Kurtosis:                       3.642   Cond. No.                     1.15e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Making Predictions using Model (test data)

# %%
X_test = stm.add_constant(X_test)
X_test.head()
# Out:
#     const  Weight  Horsepower
# 3     1.0    3433         150
# 5     1.0    4341         198
# 6     1.0    4354         220
# 20    1.0    2372          95
# 21    1.0    2833          95

# %%
## Prediction 
pred = model.predict(X_test)
pred.head(10)
# Out:
# 3     18.512209
# 5     10.871819
# 6      9.805486
# 20    27.391164
# 21    24.606284
# 22    24.872900
# 24    29.167376
# 25    32.835259
# 26    25.938078
# 28    27.373042
# dtype: float64

# %%
rss = sum((pred - y_test)**2)
rss
# Out:
# 2071.3837321647134

# %%
rmse = np.sqrt(rss/(len(y_test)-2))
rmse
# Out:
# 4.225725536729139

# %% [markdown]
# ## Plotting a Linear Regression Line

# %%
cars2.plot(kind="scatter",x="Weight",y="MPG",figsize=(8,6),grid=True)
plt.ylabel("Miles per Gallon",fontsize=12)
plt.xlabel("Weight of Cars",fontsize = 12)

#Sorted values of weight
Weight = np.sort(X_train.Weight)

#plotting the sorted values of weight with its fitted value
plt.plot(Weight,model.params[0]+model.params[1]*Weight)
plt.show()
